# %% [markdown]
# <a href="https://colab.research.google.com/github/Rwyszynski/Data-science/blob/main/Pandas2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np

# %%
s = pd.Series(data=[3,2,4,5])
a = np.nan
a
s
# Out:
# 0    3
# 1    2
# 2    4
# 3    5
# dtype: int64

# %%
s = pd.Series(data=np.arange(10, 20), index=pd.date_range(start='20200101', periods=10))
s
# Out:
# 2020-01-01    10
# 2020-01-02    11
# 2020-01-03    12
# 2020-01-04    13
# 2020-01-05    14
# 2020-01-06    15
# 2020-01-07    16
# 2020-01-08    17
# 2020-01-09    18
# 2020-01-10    19
# Freq: D, dtype: int64

# %%
s = pd.Series(data=['python','java','sql'], name='languages')
s
# Out:
# 0    python
# 1      java
# 2       sql
# Name: languages, dtype: object

# %%
price = pd.Series(data={'Apple' : 200, 'CD Projekt': 60, 'Amazon': 1900 })
price
# Out:
# Apple          200
# CD Projekt      60
# Amazon        1900
# dtype: int64

# %%
price.value_counts()
# Out:
# 200     1
# 60      1
# 1900    1
# Name: count, dtype: int64

# %%
price.describe()
# Out:
# count       3.000000
# mean      720.000000
# std      1024.304642
# min        60.000000
# 25%       130.000000
# 50%       200.000000
# 75%      1050.000000
# max      1900.000000
# dtype: float64

# %%
price.nlargest(2)
# Out:
# Amazon    1900
# Apple      200
# dtype: int64

# %%
price.rank()
# Out:
# Apple         2.0
# CD Projekt    1.0
# Amazon        3.0
# dtype: float64

# %%
price.sort_values()
# Out:
# CD Projekt      60
# Apple          200
# Amazon        1900
# dtype: int64

# %%
price.apply(lambda x: x*3.8)
# Out:
# Apple          760.0
# CD Projekt     228.0
# Amazon        7220.0
# dtype: float64

# %%
df = pd.DataFrame(data=[12,12,32])
df
# Out:
#     0
# 0  12
# 1  12
# 2  32

# %%
df = pd.DataFrame(data=[12, 12, 32], index=['first', 'second,', 'third'], columns=['col_1'])
df
# Out:
#          col_1
# first       12
# second,     12
# third       32

# %%
df.values
# Out:
# array([[12],
#        [12],
#        [32]])

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 3 entries, first to third
# Data columns (total 1 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   col_1   3 non-null      int64
# dtypes: int64(1)
# memory usage: 156.0+ bytes

# %%
df.iloc[0]
# Out:
# col_1    12
# Name: first, dtype: int64

# %%
df = pd.DataFrame(data=[12, 12, 32], index=['first', 'second,', 'third'], columns=['col_1'])
df
# Out:
#          col_1
# first       12
# second,     12
# third       32

# %%
import pandas as pd

import pandas_datareader.data as web





df = web.DataReader(name='META', data_source='stooq')

df.head()
# Out:
#                Open    High       Low   Close    Volume
# Date
# 2024-04-05  516.855  530.70  514.4099  527.34  19263265
# 2024-04-04  516.420  530.00  510.5800  510.92  26476253
# 2024-04-03  498.930  507.24  498.7500  506.74  12099171
# 2024-04-02  485.100  497.53  484.6500  497.37  11081026
# 2024-04-01  487.200  497.43  481.7800  491.35   9247007

# %%
url = 'https://storage.googleapis.com/esmartdata-courses-files/ds-bootcamp/appstore_games.csv'
df_raw = pd.read_csv(url)
df_raw.head()
# Out:
#                                                  URL         ID  \
# 0   https://apps.apple.com/us/app/sudoku/id284921427  284921427
# 1  https://apps.apple.com/us/app/reversi/id284926400  284926400
# 2  https://apps.apple.com/us/app/morocco/id284946595  284946595
# 3  https://apps.apple.com/us/app/sudoku-free/id28...  285755462
# 4  https://apps.apple.com/us/app/senet-deluxe/id2...  285831220
#
#             Name Subtitle                                           Icon URL  \
# 0         Sudoku      NaN  https://is2-ssl.mzstatic.com/image/thumb/Purpl...
# 1        Reversi      NaN  https://is4-ssl.mzstatic.com/image/thumb/Purpl...
# 2        Morocco      NaN  https://is5-ssl.mzstatic.com/image/thumb/Purpl...
# 3  Sudoku (Free)      NaN  https://is3-ssl.mzstatic.com/image/thumb/Purpl...
# 4   Senet Deluxe      NaN  https://is1-ssl.mzstatic.com/image/thumb/Purpl...
#
#    Average User Rating  User Rating Count  Price In-app Purchases  \
# ...

# %%
df.columns = [col.lower() for col in df.columns]
df.head()
# Out:
#                open    high       low   close    volume
# Date
# 2024-04-05  516.855  530.70  514.4099  527.34  19263265
# 2024-04-04  516.420  530.00  510.5800  510.92  26476253
# 2024-04-03  498.930  507.24  498.7500  506.74  12099171
# 2024-04-02  485.100  497.53  484.6500  497.37  11081026
# 2024-04-01  487.200  497.43  481.7800  491.35   9247007

# %%
df['Average'] = (df.open+df.close) / 2.0
df.head()
# Out:
#                open    high       low   close    volume   Average
# Date
# 2024-04-05  516.855  530.70  514.4099  527.34  19263265  522.0975
# 2024-04-04  516.420  530.00  510.5800  510.92  26476253  513.6700
# 2024-04-03  498.930  507.24  498.7500  506.74  12099171  502.8350
# 2024-04-02  485.100  497.53  484.6500  497.37  11081026  491.2350
# 2024-04-01  487.200  497.43  481.7800  491.35   9247007  489.2750

# %%
df = df.sort_index()
df.head()
# Out:
#               open    high     low   close    volume  Average
# Date
# 2019-04-10  178.18  178.79  176.54  177.82  11701479  178.000
# 2019-04-11  178.24  178.40  177.00  177.51   8070967  177.875
# 2019-04-12  178.00  179.63  177.95  179.10  12329812  178.550
# 2019-04-15  178.50  180.50  176.87  179.65  10834762  179.075
# 2019-04-16  179.00  180.17  178.30  178.87  11215193  178.935
